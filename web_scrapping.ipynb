# %%
import bs4 as bs
import requests
import re
import urllib.request
from selenium import webdriver

# %%
driver = webdriver.Chrome()
driver.get('https://towardsdatascience.com/understanding-lstm-and-its-quick-implementation-in-keras-for-sentiment-analysis-af410fd85b47')

# %%
r = requests.get("https://www.kdnuggets.com/2018/03/catboost-vs-light-gbm-vs-xgboost.html")
print(r.content)
# Out:
# b'<!DOCTYPE html>\n<html xmlns="http://www.w3.org/1999/xhtml" lang="en-US">\n<head profile="http://gmpg.org/xfn/11">\n  <meta http-equiv="Content-Type" content="text/html; charset=UTF-8" />\n  <meta name=viewport content="width=device-width, initial-scale=1">\n    <title>  CatBoost vs. Light GBM vs. XGBoost</title>\n  <link rel="shortcut icon" href="/wp-content/themes/kdn17/images/favicon.ico" />\n  <link type="text/css" rel="stylesheet" href="/wp-content/themes/kdn17/style.css" media="screen" />\n  <script type="text/javascript" src="/wp-content/themes/kdn17/js/jquery-1.9.1.min.js" ></script>\n  <script type="text/javascript" src="/aps/all17.js"></script> \n  <link rel="alternate" type="application/rss+xml" title="KDnuggets: Analytics, Big Data, Data Mining and Data Science Feed" href="/feed/" />\n <link rel=\'dns-prefetch\' href=\'//s.w.org\' />\n<link rel="alternate" type="application/rss+xml" title="KDnuggets &raquo; Feed" href="https://www.kdnuggets.com/feed" />\n<link rel="alte
# ...

# %%
soup = bs.BeautifulSoup(r.content,'lxml')
soup
# Out:
# <!DOCTYPE html>
# <html lang="en-US" xmlns="http://www.w3.org/1999/xhtml">
# <head profile="http://gmpg.org/xfn/11">
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>  CatBoost vs. Light GBM vs. XGBoost</title>
# <link href="/wp-content/themes/kdn17/images/favicon.ico" rel="shortcut icon"/>
# <link href="/wp-content/themes/kdn17/style.css" media="screen" rel="stylesheet" type="text/css"/>
# <script src="/wp-content/themes/kdn17/js/jquery-1.9.1.min.js" type="text/javascript"></script>
# <script src="/aps/all17.js" type="text/javascript"></script>
# <link href="/feed/" rel="alternate" title="KDnuggets: Analytics, Big Data, Data Mining and Data Science Feed" type="application/rss+xml"/>
# <link href="//s.w.org" rel="dns-prefetch"/>
# <link href="https://www.kdnuggets.com/feed" rel="alternate" title="KDnuggets » Feed" type="application/rss+xml"/>
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html xmlns="http://www.w3.org/1999/xhtml" xmlns:cc="http://creativecommons.org/ns#">
#  <head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb# medium-com: http://ogp.me/ns/fb/medium-com#">
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="width=device-width, initial-scale=1.0, viewport-fit=contain" name="viewport"/>
#   <title>
#    Understanding LSTM and its quick implementation in keras for sentiment analysis.
#   </title>
#   <link href="https://towardsdatascience.com/understanding-lstm-and-its-quick-implementation-in-keras-for-sentiment-analysis-af410fd85b47" rel="canonical"/>
#   <meta content="Understanding LSTM and its quick implementation in keras for sentiment analysis." name="title"/>
#   <meta content="always" name="referrer"/>
# ...

# %%
for x in soup.find_all(['h1','h2','h3','p']):
    print(x.text)
# Out:
# KDnuggets
# CatBoost vs. Light GBM vs. XGBoost
#
#      Who is going to win this war of predictions and on what cost? Let’s explore.
#
# By Alvira Swalin, University of San Francisco
#
# I recently participated in this Kaggle competition (WIDS Datathon by Stanford) where I was able to land up in Top 10 using various boosting algorithms. Since then, I have been very curious about the fine workings of each model including parameter tuning, pros and cons and hence decided to write this blog. Despite the recent re-emergence and popularity of neural networks, I am focusing on boosting algorithms because they are still more useful in the regime of limited training data, little training time and little expertise for parameter tuning.
#
# Since XGBoost (often called GBM Killer) has been in the machine learning world for a longer time now with lots of articles dedicated to it, this post will focus more on CatBoost & LGBM. Below are the topics we will cover-
#
# ...

# %%
soup.title.text
# Out:
# 'Label Encoder vs. One Hot Encoder in Machine Learning'

# %%
for x in soup.find_all('a'):
    print(x.get('href'))
# Out:
# https://medium.com/policy/f03bf92035c9
# https://medium.com/
# https://medium.com/
# https://medium.com/membership?source=upgrade_membership---nav_full
# https://medium.com/m/signin?redirect=https%3A%2F%2Fmedium.com%2F%40contactsunny%2Flabel-encoder-vs-one-hot-encoder-in-machine-learning-3fc273365621&source=--------------------------nav_reg&operation=login
# https://medium.com/m/signin?redirect=https%3A%2F%2Fmedium.com%2F%40contactsunny%2Flabel-encoder-vs-one-hot-encoder-in-machine-learning-3fc273365621&source=--------------------------nav_reg&operation=register
# https://medium.com/@contactsunny?source=post_header_lockup
# https://medium.com/@contactsunny?source=post_header_lockup
# http://blog.contactsunny.com/data-science/label-encoder-vs-one-hot-encoder-in-machine-learning
# http://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.LabelEncoder.html
# http://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.OneHotEncoder.html
# ...

# %%
# class_to_try = 'rn-13yce4e rn-fnigne rn-ndvcnb rn-gxnn5r rn-deolkf rn-homxoj rn-1471scf rn-14xgk7a rn-7cikom rn-o11vmf rn-ebii48 rn-gul640 rn-ad9z0x rn-1mnahxq rn-61z16t rn-p1pxzi rn-11wrixw rn-bcqeeo rn-wk8lta rn-9aemit rn-1mdbw0j rn-gy4na3 rn-bauka4 rn-irrty rn-qvutc0'

find_1 = soup.find_all("span",{"class":class_to_try})

i=1
for x in find_1:
    print('-------------------------------')
    print(i)
#     print(type(x))
    print(x.text)
    i+=1

driver.find_element_by_xpath('//*[@id="react-root"]/div[1]/main/div/div/form/div/div[3]').click()

# %%
with open('bookmarks.html', encoding="utf8") as html:
    soup=bs.BeautifulSoup(html, 'lxml')

scrape_list = []
for x in soup.find_all('a'):
    scrape_list.append(x.get('href'))

# %%
def parse(link):
    
    try:
        r = requests.get(link)
        soup = bs.BeautifulSoup(r.content,'lxml')
        
        title = soup.title.text.strip()

        pre = []
        for x in soup.find_all(['h1','h2','h3','p']):
            pre.append(x.text)
            body = ' '.join(pre).replace("\n"," ").replace("\r"," ").replace("\xa0"," ")

        hreflist = []
        for x in soup.find_all('a'):
            hreflist.append(x.get('href'))

        return [title,body,hreflist]
    
    except:
        print("didnt make it!")

# %%
title_list = []
body_list  = []
link_list  = []

for y in scrape_list[0:10]:
    title, body, hreflist = parse(y)
#     print(title)
    title_list.append(title)
    body_list.append(body)
    link_list.append(hreflist)

# %%
title_list
# Out:
# ['Getting started with PostgreSQL in R | R-bloggers',
#  'classification - How is Naive Bayes a Linear Classifier? - Cross Validated',
#  'What is the intuition behind SoftMax function? - Quora',
#  'Logistic Regression - mlxtend',
#  'linear algebra - Derivative of Softmax loss function - Mathematics Stack Exchange',
#  'An overview of gradient descent optimization algorithms',
#  'Analyzing 1000+ Greek Wines With Python | Florents Tselai',
#  'Step by step approach to do data analysis using Python',
#  '403 Forbidden',
#  'Tuning a data preprocessing pipeline with recipes and modelgrid | R-bloggers']

# %%
title, body, hreflist = parse(scrape_list[0])

# %%
body
# Out:
# 'Welcome!  Jobs for R-users Popular Searches Recent Posts Other sites Getting started with PostgreSQL in R  When dealing with large datasets that potentially exceed the memory of your machine it is nice to have another possibility such as your own server with an SQL/PostgreSQL database on it, where you can query the data in smaller digestible chunks. For example, recently I was facing a financial dataset of 5 GB. Although 5 GB fit into my RAM the data uses a lot of resources. One solution is to use an SQL-based database, where I can query data in smaller chunks, leaving resources for the computation. While MySQL is the more widely used, PostgreSQL has the advantage of being open source and free for all usages. However, we still need to get a server. One possible way to do it is to rent Amazon server, however, as I don’t have a budget for my projects and because I only need the data on my own machine I wanted to set up a server on my Windows 8.1 machine. This is how I did it. Installi
# ...
